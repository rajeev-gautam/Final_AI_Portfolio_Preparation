# %% [markdown]
# # **Object Detection using YOLO**

# %% [markdown]
# ## Importing the Libraries

# %%
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO

# %% [markdown]
# ## Loading the Model

# %%
model = YOLO("yolov8n.pt")

print("Model loaded successfully")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 2.4MB/s 2.6s.6s<0.1s2.7s1s
# Model loaded successfully

# %% [markdown]
# ## Reading the Input Image

# %%
image_path = "test.png"

img = cv2.imread(image_path)

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# ## Running Object Detection

# %%
results = model(image_path)

print("Detection completed")
# Out:
# image 1/1 C:\Users\ASUS\Desktop\coding\Python\OpenCV\Object Detection\test.png: 384x640 1 car, 67.4ms
# Speed: 2.5ms preprocess, 67.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Detection completed

# %% [markdown]
# ## Displaying the Result

# %%
res_plotted = results[0].plot()

plt.imshow(cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Detected Objects")
plt.show()

# %% [markdown]
# ## Printing Object Details

# %%
for box in results[0].boxes:
    class_id = int(box.cls[0])
    conf = float(box.conf[0])
    name = model.names[class_id]
    
    print(f"Object: {name}, Confidence: {conf:.2f}")
# Out:
# Object: car, Confidence: 0.72

# %%
print("Total objects detected:", len(results[0].boxes))
# Out:
# Total objects detected: 1
